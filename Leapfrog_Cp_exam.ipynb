# %%
"""Write a program that adds n numbers and prints the sum. 
The first input n should be the number of inputs to be taken for addition. 
Each subsequent input is a number to be added to the sum. Each input should be taken in a new line."""
# The function is expected to return an integer.
# The function accepts an integer as parameter.
 
def logic(my_input):
  # Write your code here and remove pass statement
  # You can create other functions and call from here
  # Don't print anything. Just return the intended output
  sum=0
  for _ in range(my_input):
    i_n=int(input())
    sum+=i_n
    # print('\n')
  return sum

 
 
# Do not edit below
 
# Get the input
my_input = int(input())
 
# Print output returned from the logic function
print(logic(my_input))
# Out:
# 4
# 4
# 4
# 4
# 4
# 16

# %%
# Weird Algorithm
def weird_algo(num):
  while True:
    # print(f'{num}')
    if num == 1:
      break
    if num % 2 == 0:
      num = num//2
    else:
      num = num*3+1

weird_algo(138367)

# %%
# The function is expected to return a string
# The function accepts an integer array(list of input) and an integer(length of input) as parameters.

def logic(inputs, input_length):
    # Write your code here and remove pass statement
    # You can create other functions and call from here
    # Don't print anything. Just return the intended output
    result = False
    for num in inputs:
        if '0' in str(num):
          result = True
    return 'Yes' if result else 'No'


# Do not edit below

# Get the input
input_length = int(input())
inputs = []
for x in range(input_length):
    inputs.append(int(input()))

# Print output returned from the logic function
print(logic(inputs, input_length))
# Out:
# 3
# 1
# 2
# 222
# No

# %%
# The function is expected to return a string.
# The function accepts string as parameter.

def logic(my_input):
    # Write your code here and remove pass statement
    # Don't print anything. Just return the intended output
    # You can create other functions and call from here
    vowels=['A','E','I','O','U','a','e','i','o','u']
    given_sen=list(my_input)
    d=[]
    for i,c in enumerate(given_sen):
      if c in vowels:
        d.append((i,c))
    # replace last vowel with first
    given_sen[d[-1][0]]=d[0][1]
    # replace vowels in sentence with closest except last
    for i,t in enumerate(d[1:]):
      given_sen[d[i][0]]=t[1]
    return ''.join(given_sen)  


# Do not edit below

# Get the input
my_input = input()

# Print output returned from the logic function
print(logic(my_input))
# Out:
# my name is khan
# my nemi as khan

# %%
h = [0,1,2,4,5,4]

# %%
h[-1:] + h[1:]
# Out:
# [4, 1, 2, 4, 5, 4]

# %%
# The function is expected to return an integer.
# The function accepts string as parameter.
# %%time
def logic(my_input):
    # Write your code here and remove pass statement
    # You can create other functions and call from here
    # Don't print anything. Just return the intended output
    happy = 0
    if len(my_input) == 1:
      return 0
    given_num=list(my_input)
    for i,n in enumerate(given_num):
      before=given_num[i-1] if i > 0 else None
      after=given_num[i+1]  if i < (len(given_num)-1) else None
      if n == '1':
        if (before !=0 and after !=0) and (before !=None and after !=None):
          happy+=1
        elif (before ==None or after ==None):
          num = before if before else after
          happy = happy+1 if num == n else happy
      elif int(n) == 0:
        if (before !=1 and after !=1) and (before !=None and after !=None):
          happy+=1
        elif (before ==None or after ==None):
          num = before if before else after
          happy = happy+1 if num == n else happy


    return happy
      


# Do not edit below

# Get the input
my_input = '00000'
# input()

# Print output returned from the logic function
print(logic(my_input))
# Out:
# 5
# CPU times: user 144 µs, sys: 0 ns, total: 144 µs
# Wall time: 110 µs

# %%
#Turing

# %%
c = "You can create other functions and call from here"
max_len = max(len(w) for w in c.split(" "))
max_len
c[0]
# Out:
# 'Y'

# %%
# Bhimraj Yadav
def logic(sen):
  words = sen.split(" ")
  max_len = max(len(w) for w in words)
  def get_word(w):
    diff = max_len-len(w)
    return (sen[0] * diff) + w
  sentence = " ".join(get_word(w) for w in words)
  return sentence

d = "I adore it"
logic(d)
# Out:
# 'IIIII adore IIIit'

# %% [markdown]
# ![Screenshot (86).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (85).png](data:image/png;base64,...)

# %%
# %%time
def logic(my_input):
  n_len = my_input.__len__()
  def get_neighbours(i):
    prev = my_input[i-1] if i-1>=0 else None
    next = my_input[i+1] if i+1< n_len else None
    return prev,next
  unhappy = 0
  for i,num in enumerate(my_input):
    neighbours = get_neighbours(i)
    if (neighbours[0] == neighbours[1]) and neighbours[0] !=num:
      unhappy+=1
    
    if (neighbours[0] == None) or (neighbours[1] == None):
      neighbour = neighbours[0] if neighbours[0] else neighbours[1]
      if neighbour != num:
        unhappy+=1

  return n_len - unhappy if n_len > 1 else 0


# my_input = "0110"
my_input = "00000"
logic(my_input)
# Out:
# 5

# %%
# %%time
def logic(my_input):
  n_len = my_input.__len__()
  def get_neighbours(i):
    prev = my_input[i-1] if i-1>=0 else None
    next = my_input[i+1] if i+1< n_len else None
    if prev and next :
      return prev,next
    else:
      return prev if prev else next

  unhappy = 0
  for i,num in enumerate(my_input):
    neighbours = get_neighbours(i)
    # print(num,neighbours)
    if len(neighbours) == 1:
      if neighbours != num:
        unhappy+=1
    else:
      if (neighbours[0] == neighbours[1]) and neighbours[0] !=num:
        unhappy+=1

  return n_len - unhappy if n_len > 1 else 0


my_input = "0110"
my_input = "00000"
logic(my_input)
# Out:
# 5

# %%
def logic(my_input):
  sum=0
  for i,num in enumerate(my_input):
    sum += int(num) ** int(my_input[i-1])
  return sum

my_input = "145"
logic(my_input)
# Out:
# 630

# %%
def logic(my_input):
  dust = "dustDUST"
  count = 0
  for c in dust:
    if c in my_input:
      my_input = my_input.replace(c,"")
      count +=1
  if count == 0:
    return "It's clean floor!"
  return my_input

my_input = "DusttttdustTTbinDust"
# my_input = "floor"
logic(my_input)
# Out:
# 'bin'

# %%
def logic(my_input):
  def my_func(num):
    l = len(num)
    mid = l // 2 if l % 2 == 0 else l // 2 + 1
    sum = 0
    for i in range(l // 2):
      sum += int(num[i]) * int(num[-i-1])
    if l % 2 != 0:
      sum += int(num[mid-1])
    return str(sum)

  while(len(my_input) != 1):
    my_input = my_func(my_input)

  return int(my_input)

my_input = "3456457"
logic(my_input)
# Out:
# 8

# %%
# replace vowel
def logic(my_input):
  vowels = "aeiouAEIOU" 
  given_str = list(my_input)
  d = []
  for i,c in enumerate(given_str):
    if c in vowels:
      d.append((i,c))
  # print(d)
  for i in range(len(d)):
    # print(d[i-1][0],d[i][1])
    given_str[d[i-1][0]] = d[i][1]

  return "".join(given_str)
# my_input = "Hello World"
my_input = "Me name Is Khan"

logic(my_input)
# Out:
# 'Ma nemI as Khen'

# %%
# Q1
def logic(my_input):

  sum = 0
  for num in my_input:
    if num > 1:
      for i in range(2, int(num/2)+1):
          if (num % i) == 0:
              break
          else:
              sum+= num **2

  return sum
  



my_input = [8,16]

logic(my_input)
# Out:
# 0

# %%
# The function is expected to return an integer.
# The function accepts an integer array(list of input) and an integer(length of input) as parameters.

def logic(inputs, input_length):
  # Write your code here and remove pass statement
  # You can create other functions and call from here
  # Don't print anything. Just return the intended output
  sum = 0
  for num in inputs:
    if num > 1:
      for i in range(2, int(num/2)+1):
          if (num % i) == 0:
              break
          else:
              sum+= num **2

  return sum


# Do not edit below

# Get the input
input_length = int(input())
inputs = []
for x in range(input_length):
    inputs.append(int(input()))

# Print output returned from the logic function
print(logic(inputs, input_length))
# Out:
# 2
# 8
# 16
# 0

# %%
# The function is expected to return an integer.
# The function accepts an string array(list of input) and an integer(length of input) as parameters.

def logic(inputs, input_length):
    # Write your code here and remove pass statement
    # You can create other functions and call from here
    # Don't print anything. Just return the intended output
    total = 0
    if input_length < 2 :
      return 0
    for c in inputs[0]:
      count = 0
      for word in inputs:
        if c in word:
          count +=1
      if count == input_length:
        total +=1
        
    return total



# Do not edit below

# Get the input
input_length = int(input())

inputs = []
for x in range(input_length):
    inputs.append(input())

# Print output returned from the logic function
print(logic(inputs, input_length))
# Out:
# 2
# asd
# ad
# 2

# %%
# The function is expected to return a string.
# The function accepts string as parameter.

def logic(my_input):
    # Write your code here and remove pass statement
    # Don't print anything. Just return the intended output
    # You can create other functions and call from here
    pairs = []
    count_zero = 0
    count_one = 0
    for i in range(len(my_input)-1):
      pairs.append(my_input[i]+ my_input[i+1])
    
    # for p in pairs:
    #   if p == "00":
    #     count_zero +=1
    #   if p == "11":
    #     count_one +=1
    print(pairs)
  


# Do not edit below

# Get the input
# my_input = input()
my_input = "0010000111"

# Print output returned from the logic function
print(logic(my_input))
# Out:
# ['00', '01', '10', '00', '00', '00', '01', '11', '11']
# None

# %%
# The function is expected to return a string.
# The function accepts string as parameter.

def logic(my_input):
    # Write your code here and remove pass statement
    # Don't print anything. Just return the intended output
    # You can create other functions and call from here
    result = True
    # counts zeros
    c0 = 0;
    # counts ones
    c1 = 0;

    for digit in my_input:
      if (digit == '0'):
          if (c1 % 2 == 0 and c1 != 0):
            result = False;
            break
          c1 = 0;
      # count consecutive 0's
          c0 = c0 + 1;
        
      else :
          if (c0 % 2 == 1 and c0 != 0):
            result = False;
            break
          c0 = 0;

          # count consecutive 1's
          c1 = c1 + 1;

    if result == True:
      return "Yes"
    else:
      return "No"
  


# Do not edit below

# Get the input
# my_input = input()
my_input = "0010000111"
# my_input = "0100111"

# Print output returned from the logic function
print(logic(my_input))
# Out:
# Yes

# %%
def logic(my_input):
    if(not valid_input(my_input)):
        return "Invalid input sequence"
    n_len = my_input.__len__()
    def get_neighbours(i):
        prev = my_input[i-1] if i-1>=0 else None
        next = my_input[i+1] if i+1< n_len else None
        if prev and next :
            return prev,next
        else:
            return prev if prev else next
    unhappy = 0
    for i,num in enumerate(my_input):
        neighbours = get_neighbours(i)
        # print(num,neighbours)
        if len(neighbours) == 1:
            if neighbours != num:
                unhappy+=1
        else:
            if (neighbours[0] == neighbours[1]) and neighbours[0] !=num:
                unhappy+=1
    return n_len - unhappy if n_len > 1 else 0
def valid_input(my_input):
    for i in my_input:
        if i == '1' or i == '0':
            continue
        else:
            return False 
    return True
my_input = input()
print(logic(my_input))
